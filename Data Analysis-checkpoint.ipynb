# %%
grouped = M2I.groupby(['Timbre Class', 'Tempo'])

# BOWED STRINGS
bowed_string_fast = grouped.get_group(('Bowed Strings', 'Fast'))
bowed_string_medium = grouped.get_group(('Bowed Strings', 'Moderate'))
bowed_string_slow = grouped.get_group(('Bowed Strings', 'Slow'))

bowed_string_all_tempos = pd.concat([bowed_string_fast, bowed_string_medium, bowed_string_slow])

sns.boxplot(data=bowed_string_all_tempos, x='Tempo', y='Hue')
plt.xlabel('Tempo')
plt.ylabel('Hue')
plt.title('Hue Values for Bowed Strings at All Tempos')
plt.show()

# Filter the data for bowed strings only
bowed_strings = M2I[M2I['Timbre Class'] == 'Bowed Strings']

# Compute the median Hue values for each tempo group
bowed_string_fast = bowed_strings[bowed_strings['Tempo'] == 'Fast']['Hue'].median()
bowed_string_medium = bowed_strings[bowed_strings['Tempo'] == 'Moderate']['Hue'].median()
bowed_string_slow = bowed_strings[bowed_strings['Tempo'] == 'Slow']['Hue'].median()

# Print the median values
print("Median values for Bowed Strings at all tempos:")
print(f"Fast: {bowed_string_fast}")
print(f"Moderate: {bowed_string_medium}")
print(f"Slow: {bowed_string_slow}")
# Out:
# Median values for Bowed Strings at all tempos:
# Fast: 190.0
# Moderate: 45.0
# Slow: 80.0

# %%
# PERCUSSION
percussion_fast = grouped.get_group(('Percussion', 'Fast'))
percussion_medium = grouped.get_group(('Percussion', 'Moderate'))
percussion_slow = grouped.get_group(('Percussion', 'Slow'))

percussion_all_tempos = pd.concat([percussion_fast, percussion_medium, percussion_slow])

sns.boxplot(data=percussion_all_tempos, x='Tempo', y='Hue')
plt.xlabel('Tempo')
plt.ylabel('Hue')
plt.title('Hue Values for Percussion at All Tempos')
plt.show()

# Filter the data for percussion only
percussion = M2I[M2I['Timbre Class'] == 'Percussion']

# Compute the median Hue values for each tempo group
percussion_fast = percussion[percussion['Tempo'] == 'Fast']['Hue'].median()
percussion_medium = percussion[percussion['Tempo'] == 'Moderate']['Hue'].median()
percussion_slow = percussion[percussion['Tempo'] == 'Slow']['Hue'].median()

# Print the median values
print("Median values for Percussion at all tempos:")
print(f"Fast: {percussion_fast}")
print(f"Moderate: {percussion_medium}")
print(f"Slow: {percussion_slow}")
# Out:
# Median values for Percussion at all tempos:
# Fast: 190.0
# Moderate: 80.0
# Slow: 80.0

# %%
# BRASS
brass_fast = grouped.get_group(('Brass', 'Fast'))
brass_medium = grouped.get_group(('Brass', 'Moderate'))
brass_slow = grouped.get_group(('Brass', 'Slow'))

brass_all_tempos = pd.concat([brass_fast, brass_medium, brass_slow])

sns.boxplot(data=brass_all_tempos, x='Tempo', y='Hue')
plt.xlabel('Tempo')
plt.ylabel('Hue')
plt.title('Hue Values for Brass at All Tempos')
plt.show()

# Filter the data for brass only
brass = M2I[M2I['Timbre Class'] == 'Brass']

# Compute the median Hue values for each tempo group
brass_fast = brass[brass['Tempo'] == 'Fast']['Hue'].median()
brass_medium = brass[brass['Tempo'] == 'Moderate']['Hue'].median()
brass_slow = brass[brass['Tempo'] == 'Slow']['Hue'].median()

# Print the median values
print("Median values for Brass at all tempos:")
print(f"Fast: {brass_fast}")
print(f"Moderate: {brass_medium}")
print(f"Slow: {brass_slow}")
# Out:
# Median values for Brass at all tempos:
# Fast: 15.0
# Moderate: 30.0
# Slow: 80.0

# %%
# WOODWIND
woodwind_fast = grouped.get_group(('Woodwind', 'Fast'))
woodwind_medium = grouped.get_group(('Woodwind', 'Moderate'))
woodwind_slow = grouped.get_group(('Woodwind', 'Slow'))

woodwind_all_tempos = pd.concat([woodwind_fast, woodwind_medium, woodwind_slow])

sns.boxplot(data=woodwind_all_tempos, x='Tempo', y='Hue')
plt.xlabel('Tempo')
plt.ylabel('Hue')
plt.title('Hue Values for Woodwind at All Tempos')
plt.show()

# Filter the data for woodwind only
woodwind = M2I[M2I['Timbre Class'] == 'Woodwind']

# Compute the median Hue values for each tempo group
woodwind_fast = woodwind[woodwind['Tempo'] == 'Fast']['Hue'].median()
woodwind_medium = woodwind[woodwind['Tempo'] == 'Moderate']['Hue'].median()
woodwind_slow = woodwind[woodwind['Tempo'] == 'Slow']['Hue'].median()

# Print the median values
print("Median values for Woodwind at all tempos:")
print(f"Fast: {woodwind_fast}")
print(f"Moderate: {woodwind_medium}")
print(f"Slow: {woodwind_slow}")
# Out:
# Median values for Woodwind at all tempos:
# Fast: 30.0
# Moderate: 45.0
# Slow: 77.5

# %%
# PLUCKED STRINGS
plucked_fast = grouped.get_group(('Plucked Strings', 'Fast'))
plucked_medium = grouped.get_group(('Plucked Strings', 'Moderate'))
plucked_slow = grouped.get_group(('Plucked Strings', 'Slow'))

plucked_all_tempos = pd.concat([plucked_fast, plucked_medium, plucked_slow])

sns.boxplot(data=plucked_all_tempos, x='Tempo', y='Hue')
plt.xlabel('Tempo')
plt.ylabel('Hue')
plt.title('Hue Values for Plucked Strings at All Tempos')
plt.show()

plucked_strings = M2I[M2I['Timbre Class'] == 'Plucked Strings']

# Compute the median Hue values for each tempo group
plucked_fast = plucked_strings[plucked_strings['Tempo'] == 'Fast']['Hue'].median()
plucked_medium = plucked_strings[plucked_strings['Tempo'] == 'Moderate']['Hue'].median()
plucked_slow = plucked_strings[plucked_strings['Tempo'] == 'Slow']['Hue'].median()

# Print the median values
print("Median values for Plucked Strings at all tempos:")
print(f"Fast: {plucked_fast}")
print(f"Moderate: {plucked_medium}")
print(f"Slow: {plucked_slow}")
# Out:
# Median values for Plucked Strings at all tempos:
# Fast: 62.5
# Moderate: 135.0
# Slow: 80.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the correlation matrix
corr_matrix = [[1, 0.06331652, 0.010413887, 0.185767789],
               [0.06331652, 1, 0.044177594, -0.199432058],
               [0.010413887, 0.044177594, 1, -0.038097457],
               [0.185767789, -0.199432058, -0.038097457, 1]]

# Create the heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', 
            xticklabels=['TempoNum', 'Hue', 'Saturation', 'Value'], 
            yticklabels=['TempoNum', 'Hue', 'Saturation', 'Value'])

# Set the axis labels and title
plt.xlabel('Features')
plt.ylabel('Features')
plt.title('Correlation Matrix')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
import colorsys

# read the CSV file into a DataFrame
df = pd.read_csv('Data - M2I.csv')
filtered_df = df[df['Timbre Class'] == 'Bowed Strings']

# create the figure and 3D axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# create RGB color values for each point
colors = []
for i in range(len(filtered_df)):
    hsv = (filtered_df['Hue'].iloc[i]/360, filtered_df['Saturation'].iloc[i], filtered_df['Value'].iloc[i])
    rgb = colorsys.hsv_to_rgb(*hsv)
    colors.append(rgb)

# scatter plot with Hue, Saturation, and Brightness as x, y, and z axes
ax.scatter(filtered_df['Hue'], filtered_df['Saturation'], filtered_df['Value'], c=colors, alpha=0.5)

# set labels for each axis
ax.set_xlabel('Hue')
ax.set_ylabel('Saturation')
ax.set_zlabel('Brightness')

# set title for the plot
ax.set_title('3D Scatter Plot of Hue, Saturation, and Brightness (Bowed Strings)')

# get number of points
num_points = len(filtered_df)
print("Number of points:", num_points)

plt.show()
# Out:
# Number of points: 42

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
import colorsys

# read the CSV file into a DataFrame
df = pd.read_csv('Data - M2I.csv')
filtered_df = df[df['Timbre Class'] == 'Percussion']

# create the figure and 3D axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# create RGB color values for each point
colors = []
for i in range(len(filtered_df)):
    hsv = (filtered_df['Hue'].iloc[i]/360, filtered_df['Saturation'].iloc[i], filtered_df['Value'].iloc[i])
    rgb = colorsys.hsv_to_rgb(*hsv)
    colors.append(rgb)

# scatter plot with Hue, Saturation, and Brightness as x, y, and z axes
ax.scatter(filtered_df['Hue'], filtered_df['Saturation'], filtered_df['Value'], c=colors, alpha=0.5)

# set labels for each axis
ax.set_xlabel('Hue')
ax.set_ylabel('Saturation')
ax.set_zlabel('Brightness')

# set title for the plot
ax.set_title('3D Scatter Plot of Hue, Saturation, and Brightness (Percussion)')

# get number of points
num_points = len(filtered_df)
print("Number of points:", num_points)

plt.show()
# Out:
# Number of points: 42

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
import colorsys

# read the CSV file into a DataFrame
df = pd.read_csv('Data - M2I.csv')
filtered_df = df[df['Timbre Class'] == 'Woodwind']

# create the figure and 3D axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# create RGB color values for each point
colors = []
for i in range(len(filtered_df)):
    hsv = (filtered_df['Hue'].iloc[i]/360, filtered_df['Saturation'].iloc[i], filtered_df['Value'].iloc[i])
    rgb = colorsys.hsv_to_rgb(*hsv)
    colors.append(rgb)

# scatter plot with Hue, Saturation, and Brightness as x, y, and z axes
ax.scatter(filtered_df['Hue'], filtered_df['Saturation'], filtered_df['Value'], c=colors, alpha=0.5)

# set labels for each axis
ax.set_xlabel('Hue')
ax.set_ylabel('Saturation')
ax.set_zlabel('Brightness')

# set title for the plot
ax.set_title('3D Scatter Plot of Hue, Saturation, and Brightness (Woodwind)')

# get number of points
num_points = len(filtered_df)
print("Number of points:", num_points)

plt.show()
# Out:
# Number of points: 42

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
import colorsys

# read the CSV file into a DataFrame
df = pd.read_csv('Data - M2I.csv')
filtered_df = df[df['Timbre Class'] == 'Brass']

# create the figure and 3D axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# create RGB color values for each point
colors = []
for i in range(len(filtered_df)):
    hsv = (filtered_df['Hue'].iloc[i]/360, filtered_df['Saturation'].iloc[i], filtered_df['Value'].iloc[i])
    rgb = colorsys.hsv_to_rgb(*hsv)
    colors.append(rgb)

# scatter plot with Hue, Saturation, and Brightness as x, y, and z axes
ax.scatter(filtered_df['Hue'], filtered_df['Saturation'], filtered_df['Value'], c=colors, alpha=0.5)

# set labels for each axis
ax.set_xlabel('Hue')
ax.set_ylabel('Saturation')
ax.set_zlabel('Brightness')

# set title for the plot
ax.set_title('3D Scatter Plot of Hue, Saturation, and Brightness (Brass)')

# get number of points
num_points = len(filtered_df)
print("Number of points:", num_points)

plt.show()
# Out:
# Number of points: 42

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
import colorsys

# read the CSV file into a DataFrame
df = pd.read_csv('Data - M2I.csv')
filtered_df = df[df['Timbre Class'] == 'Plucked Strings']

# create the figure and 3D axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# create RGB color values for each point
colors = []
for i in range(len(filtered_df)):
    hsv = (filtered_df['Hue'].iloc[i]/360, filtered_df['Saturation'].iloc[i], filtered_df['Value'].iloc[i])
    rgb = colorsys.hsv_to_rgb(*hsv)
    colors.append(rgb)

# scatter plot with Hue, Saturation, and Brightness as x, y, and z axes
ax.scatter(filtered_df['Hue'], filtered_df['Saturation'], filtered_df['Value'], c=colors, alpha=0.5)

# set labels for each axis
ax.set_xlabel('Hue')
ax.set_ylabel('Saturation')
ax.set_zlabel('Brightness')

# set title for the plot
ax.set_title('3D Scatter Plot of Hue, Saturation, and Brightness (Plucked Strings)')

# get number of points
num_points = len(filtered_df)
print("Number of points:", num_points)

plt.show()
# Out:
# Number of points: 42

# %%
import pandas as pd
import seaborn as sns

# read the CSV file into a DataFrame
df = pd.read_csv('Data - M2I.csv')

# create the box plot for hue
sns.boxplot(x='Mode', y='Hue', data=df)
plt.xlabel('Mode')
plt.ylabel('Hue')
plt.show()

# create the box plot for saturation
sns.boxplot(x='Mode', y='Saturation', data=df)
plt.xlabel('Mode')
plt.ylabel('Saturation')
plt.show()

# create the box plot for value
sns.boxplot(x='Mode', y='Value', data=df)
plt.xlabel('Mode')
plt.ylabel('Value')
plt.show()

# %%
import pandas as pd
import seaborn as sns

# read the CSV file into a DataFrame
df = pd.read_csv('Data - I2M.csv')

# create the box plot for hue
sns.boxplot(x='Mode', y='Hue', data=df)
plt.xlabel('Mode')
plt.ylabel('Hue')
plt.show()

# create the box plot for saturation
sns.boxplot(x='Mode', y='Saturation', data=df)
plt.xlabel('Mode')
plt.ylabel('Saturation')
plt.show()

# create the box plot for value
sns.boxplot(x='Mode', y='Value', data=df)
plt.xlabel('Mode')
plt.ylabel('Value')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
import colorsys

# read the CSV file into a DataFrame
df = pd.read_csv('Data - M2I.csv')
filtered_df = df[df['Timbre Class'] == 'Brass']

# create the figure and 3D axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# create RGB color values for each point
colors = []
for i in range(len(filtered_df)):
    hsv = (filtered_df['Hue'].iloc[i]/360, filtered_df['Saturation'].iloc[i], filtered_df['Value'].iloc[i])
    rgb = colorsys.hsv_to_rgb(*hsv)
    colors.append(rgb)

# scatter plot with Hue, Saturation, and Brightness as x, y, and z axes
ax.scatter(filtered_df['Hue'], filtered_df['Saturation'], filtered_df['Value'], c=colors, alpha=0.5)

# set labels for each axis
ax.set_xlabel('Hue')
ax.set_ylabel('Saturation')
ax.set_zlabel('Brightness')

# set title for the plot
ax.set_title('3D Scatter Plot of Hue, Saturation, and Brightness (Brass)')

# get number of points
num_points = len(filtered_df)
print("Number of points:", num_points)

plt.show()
